# %%
#merge
import pandas as pd
student=pd.DataFrame(
       {
        'studentid':[101,102,103,104,105],
    'studentname':['joy','nisihant','sham','ram','nukul'],
         'age':[12,13,14,15,16],
         }

)

score=pd.DataFrame(
        {
         'studentid':[101,102,103,104,],
         'subject':['maths','science','english','history'],
          'score':[34,56,78,90],
          }
)

print(student)
print(score)
# Out:
#    studentid studentname  age
# 0        101         joy   12
# 1        102    nisihant   13
# 2        103        sham   14
# 3        104         ram   15
# 4        105       nukul   16
#    studentid  subject  score
# 0        101    maths     34
# 1        102  science     56
# 2        103  english     78
# 3        104  history     90
